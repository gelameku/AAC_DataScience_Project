# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import plotly.express as px
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **Location or Size: What Influences House Prices in Mexico?**

# %% [markdown]
# - We've wrangled the data,
# - We've gained an understanding of its basic characteristics in our EDA, and
# - Now, it's time to ask some research questions.

# %% [markdown]
# #### Import Data

# %%
df = pd.read_csv("C:/Users/user/DSFolder/mx/mexicoData_clean.csv")

# %%
df.head(3)
# Out:
#   property_type             state        lat         lon  area_m2  price_usd
# 0         house  Estado de México  19.560181  -99.233528      150   67965.56
# 1         house        Nuevo León  25.688436 -100.198807      186   63223.78
# 2     apartment          Guerrero  16.767704  -99.764383       82   84298.37

# %% [markdown]
# **Q1:Which state has the most expensive real estate market?**

# %% [markdown]
# - Do housing prices vary by state?
# - If so, which are the most expensive states for purchasing a home?

# %%
# Declare variable `mpbs = mean_price_by_state`
mpbs = df.groupby("state")["price_usd"].mean().sort_values(ascending=False)
# Print object type, shape, and head
print(type(mpbs))
print(mpbs.shape)
mpbs
# Out:
# <class 'pandas.core.series.Series'>
# (30,)
# state
# Querétaro                          139738.576641
# Guanajuato                         136765.620000
# Chihuahua                          135854.568500
# Quintana Roo                       135264.797895
# Nuevo León                         134249.349277
# Distrito Federal                   134081.427558
# Jalisco                            129747.298167
# Estado de México                   127813.455028
# Puebla                             127697.343684
# Guerrero                           126877.402041
# Campeche                           121734.633333
# Sonora                             120972.508333
# Aguascalientes                     116917.591000
# Morelos                            116526.881500
# Baja California Sur                114393.786000
# Yucatán                            113622.297310
# Chiapas                            107270.194182
# Veracruz de Ignacio de la Llave    100944.446325
# Tamaulipas                          99218.728333
# Hidalgo                             98213.811765
# Sinaloa                             97884.878462
# San Luis Potosí                     96196.535636
# Nayarit                             94444.710000
# Durango                             85261.900000
# Tabasco                             84579.062000
# Tlaxcala                            79257.625000
# Zacatecas                           76395.400000
# Colima                              67491.986000
# Baja California                     67346.284138
# Oaxaca                              59681.585000
# Name: price_usd, dtype: float64

# %%
# Create bar chart from `mean_price_by_state` using pandas
mpbs.plot(
    kind="bar",
    xlabel="state",
    ylabel="Price[USD]",
    title="Mean House Price by State"
);

# %% [markdown]
# Querétaro would be the most expensive real estate market in Mexico.

# %% [markdown]
# Create a new column in `df` called `"price_per_m2"`.

# %%
# Create "price_per_m2" column
df["price_per_m2"] = df["price_usd"]/df["area_m2"]

# Print object type, shape, and head
print("df type:", type(df))
print("df shape:", df.shape)
df.head()
# Out:
# df type: <class 'pandas.core.frame.DataFrame'>
# df shape: (1736, 7)
#   property_type             state        lat         lon  area_m2  price_usd  \
# 0         house  Estado de México  19.560181  -99.233528      150   67965.56
# 1         house        Nuevo León  25.688436 -100.198807      186   63223.78
# 2     apartment          Guerrero  16.767704  -99.764383       82   84298.37
# 3     apartment          Guerrero  16.829782  -99.911012      150   94308.80
# 4         house           Yucatán  21.052583  -89.538639      205  105191.37
#
#    price_per_m2
# 0    453.103733
# 1    339.912796
# 2   1028.028902
# 3    628.725333
# 4    513.128634

# %%
# Group `df` by "state", create bar chart of "price_per_m2"
(
    df
    .groupby("state")
    ["price_per_m2"].mean()
    .sort_values(ascending=False)
    .plot(
        kind="bar",
        xlabel="State",
        ylabel="Mean Price per M^2[USD]",
        title="Mean House Price per M^2 by State"
    )
);

# %% [markdown]
# Now we see that the capital Mexico City (*Distrito Federal*) is by far the most expensive market.

# %% [markdown]
# **Q2:Is there a relationship between home size and price?**

# %% [markdown]
# A scatter plot can be helpful when evaluating the relationship between two columns because it lets you see if two variables are correlated — in this case, if an increase in home size is associated with an increase in price.

# %%
# Create scatter plot of "price_usd" vs "area_m2"
plt.scatter(x=df["area_m2"],y=df["price_usd"])
# Add x-axis label
plt.xlabel("Area[Sq meters]")
# Add y-axis label
plt.ylabel("Price[USD]")
# Add title
plt.title("Price vs Area");

# %% [markdown]
# While there's a good amount of variation, there's definitely a positive correlation — in other words, the bigger the house, the higher the price. But how can we quantify this correlation?

# %% [markdown]
# Using the `corr` method, calculate the Pearson correlation coefficient for `"area_m2"` and `"price_usd"`.

# %%
# Calculate correlation of "price_usd" and "area_m2"
p_correlation = df["area_m2"].corr(df["price_usd"])

# Print correlation coefficient
print("Correlation of 'area_m2' and 'price_usd' (all Mexico):", p_correlation)
# Out:
# Correlation of 'area_m2' and 'price_usd' (all Mexico): 0.5820852654220688

# %% [markdown]
# The correlation coefficient is over 0.5, so there's a moderate relationship house size and price in Mexico.
